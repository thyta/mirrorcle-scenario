# %%
import pandas as pd
import re

# %%
df = pd.read_excel("store\.xlsx")

# %%
df
# Out:
#                  Vùng Chi nhánh Số hợp đồng    Người tạo yêu cầu Loại dịch vụ  \
# 0    07.Hồ Chí Minh    HCM_01   SGAAB0147          tuanbq2.tin     Internet
# 1    07.Hồ Chí Minh    HCM_01   SGAAB0156             namnh178     FPT Play
# 2    07.Hồ Chí Minh    HCM_01   SGAAB2614           haipv3.tin   FPT Camera
# 3    07.Hồ Chí Minh    HCM_01   SGAAB2862             giangnt1     Internet
# 4    07.Hồ Chí Minh    HCM_01   SGAAB7344  phuongnam.chuongnpn     Internet
# ..                ...       ...         ...                  ...          ...
# 195  07.Hồ Chí Minh    HCM_15   SGJ119247          tuanbq2.tin     Internet
# 196  07.Hồ Chí Minh    HCM_15   SGJ126307              tinhnt7     Internet
# 197  07.Hồ Chí Minh    HCM_16   SGAAC5456               luanpc     Internet
# 198  07.Hồ Chí Minh    HCM_16   SGAAE0877    phuongnam.duylnk1     Internet
# 199  07.Hồ Chí Minh    HCM_16   SGAAG0045     phuongnam.taipq1     Internet
#
#                                     Nội dung tiếp nhận      Ngày tiếp nhận  \
# 0    call - LÂM HỒNG PHÚ - SGAAB0147 - 0946210462 -... 2024-11-06 12:37:14
# 1    SGAAB0156 - 0908020082 - có 1 Camera ko kết nố... 2024-11-05 12:57:13
# 2    SGAAB2614 - 0908991897 - CÔNG TY TNHH GLOBAL S... 2024-11-02 10:35:23
# 3    SGAAB2862 - 0933662540 - NGUYỄN THỊ DIỄM HẰNG:... 2024-11-07 12:03:16
# 4    SGAAB7344 - 0944534350 - so chinh chu:  kh báo... 2024-11-14 10:19:23
# ..                                                 ...                 ...
# 195  SGJ119247 - 0944333696 - cc:   KH yêu cầu than... 2024-11-08 11:38:19
# 196  Huỳnh Thị Từ Quyên - SGJ126307, 0342439048, c.... 2024-11-09 11:06:20
# 197  DUONG DINH THIEN NHAN - SGAAC5456 - 0972719402... 2024-11-04 12:12:02
# 198  TU SANG THUAN - SGAAE0877 - 0907437400 - CC: k... 2024-11-07 16:04:03
# 199  SGAAG0045 - 0974188388 - C. Thủy: KH muốn th-l... 2024-11-12 10:17:23
#
#          Ngày phân công  Kết quả liên lạc                   Kết quả xử lý  \
# 0   2024-11-06 12:37:14  Gặp trực tiếp KH             KH đồng ý dùng tiếp
# 1   2024-11-05 14:25:00  Gặp trực tiếp KH  CS đã giải đáp thắc mắc cho KH
# 2   2024-11-02 10:35:23  Gặp trực tiếp KH  CS đã giải đáp thắc mắc cho KH
# 3   2024-11-07 12:03:16  Gặp trực tiếp KH             KH đồng ý dùng tiếp
# 4   2024-11-14 10:19:23  Gặp trực tiếp KH  CS đã giải đáp thắc mắc cho KH
# ..                  ...               ...                             ...
# 195 2024-11-08 11:38:19  Gặp trực tiếp KH             KH đồng ý dùng tiếp
# 196 2024-11-09 11:06:20  Gặp trực tiếp KH             KH đồng ý dùng tiếp
# 197 2024-11-04 12:12:02  Gặp trực tiếp KH             KH đồng ý dùng tiếp
# 198 2024-11-07 16:04:03  Gặp trực tiếp KH             KH đồng ý dùng tiếp
# 199 2024-11-12 10:17:23  Gặp trực tiếp KH  CS đã giải đáp thắc mắc cho KH
#
#      ... Người xử lý lần đầu Người xử lý hiện tại Thời gian xử lý hoàn tất  \
# 0    ...               Mydc2                Mydc2      2024-11-07 09:34:18
# 1    ...          phuongnhb2           phuongnhb2      2024-11-08 09:18:20
# 2    ...              Hongnk               Hongnk      2024-11-02 11:50:31
# 3    ...           Dungnt276            Dungnt276      2024-11-08 14:52:58
# 4    ...             Quyntx3              Quyntx3      2024-11-14 11:08:12
# ..   ...                 ...                  ...                      ...
# 195  ...             KhoiLTD              KhoiLTD      2024-11-08 13:56:15
# 196  ...   Phuongnam.PhucPTH    Phuongnam.PhucPTH      2024-11-13 14:22:35
# 197  ...           quynhnt58            quynhnt58      2024-11-05 15:59:14
# 198  ...               Vytnm                Vytnm      2024-11-08 09:08:33
# 199  ...            Thinhntc             Thinhntc                      NaT
#
#     Tình trạng xử lý của yêu cầu Gói dịch vụ Gói DV tính cước  \
# 0                       Đã xử lý         Sky              Sky
# 1                       Đã xử lý        Meta             Meta
# 2                       Đã xử lý        Meta             Meta
# 3                       Đã xử lý        Giga             Giga
# 4                       Đã xử lý         Sky              Sky
# ..                           ...         ...              ...
# 195                     Đã xử lý        Giga             Giga
# 196        Kết thúc theo yêu cầu        Giga             Giga
# 197                     Đã xử lý        Giga             Giga
# 198                     Đã xử lý        Meta             Meta
# 199                   Đang xử lý         Sky              Sky
#
#     Số tháng sử dụng    Tình trạng NET hiện tại Tình trạng PayTV hiện tại  \
# 0                 34                Bình thường               Bình thường
# 1                 34                Bình thường               Bình thường
# 2                 33                Bình thường                       NaN
# 3                 33                Bình thường               Bình thường
# 4                 33                Bình thường               Bình thường
# ..               ...                        ...                       ...
# 195               35                Bình thường               Bình thường
# 196               35                Bình thường                       NaN
# 197               33  Ngưng vì lý do thanh toán               Bình thường
# 198               33                Bình thường                       NaN
# 199               32                Bình thường               Bình thường
#
#     Tình trạng NET khi lên CR
# 0                 Bình thường
# 1                 Bình thường
# 2                 Bình thường
# 3                 Bình thường
# 4                 Bình thường
# ..                        ...
# 195               Bình thường
# 196               Bình thường
# 197               Bình thường
# 198               Bình thường
# 199               Bình thường
#
# [200 rows x 31 columns]

# %%
# # Define a function to extract Vietnamese phone numbers
# def extract_phone_numbers(text):
#     # Regex pattern for Vietnamese phone numbers
#     pattern = r'\b(0[3|5|7|8|9]\d{8})\b'
#     # Find all matches
#     matches = re.findall(pattern, text)
#     # Join all found numbers (if multiple numbers in the text)
#     return ', '.join(matches) if matches else None
def extract_phone_numbers(text):
    # Convert any non-string value to a string
    if not isinstance(text, str):
        text = str(text)
    
    # Regex pattern for Vietnamese phone numbers
    pattern = r'\b(0[3|5|7|8|9]\d{8})\b'
    # Find all matches
    matches = re.findall(pattern, text)
    # Join all found numbers (if multiple numbers in the text)
    return ', '.join(matches) if matches else None

# %%
def doit(df):
    # Create a new column for phone numbers
    df['phone_numbers 1'] = df['Nội dung xử lý'].apply(extract_phone_numbers)
    df['phone_numbers 2'] = df['Nội dung tiếp nhận'].apply(extract_phone_numbers)
    # Insert 'phone_numbers' as the first column
    df.insert(0, 'phone_numbers 1', df.pop('phone_numbers 1'))
    # df.insert(1, 'phone_numbers 2', df.pop('phone_numbers 2'))
    return df

# %%
doit(df)
# Out:
#                         phone_numbers 1              Vùng Chi nhánh  \
# 0    0921280579, 0946210462, 0921280579  07.Hồ Chí Minh    HCM_01
# 1                0908020082, 0908020082  07.Hồ Chí Minh    HCM_01
# 2                            0908991897  07.Hồ Chí Minh    HCM_01
# 3                            0933662540  07.Hồ Chí Minh    HCM_01
# 4                            0944534350  07.Hồ Chí Minh    HCM_01
# ..                                  ...               ...       ...
# 195                                None  07.Hồ Chí Minh    HCM_15
# 196  0342439048, 0342439048, 0974487255  07.Hồ Chí Minh    HCM_15
# 197                          0972719402  07.Hồ Chí Minh    HCM_16
# 198              0907437400, 0907437400  07.Hồ Chí Minh    HCM_16
# 199                          0974188388  07.Hồ Chí Minh    HCM_16
#
#     Số hợp đồng    Người tạo yêu cầu Loại dịch vụ  \
# 0     SGAAB0147          tuanbq2.tin     Internet
# 1     SGAAB0156             namnh178     FPT Play
# 2     SGAAB2614           haipv3.tin   FPT Camera
# 3     SGAAB2862             giangnt1     Internet
# 4     SGAAB7344  phuongnam.chuongnpn     Internet
# ..          ...                  ...          ...
# 195   SGJ119247          tuanbq2.tin     Internet
# 196   SGJ126307              tinhnt7     Internet
# 197   SGAAC5456               luanpc     Internet
# 198   SGAAE0877    phuongnam.duylnk1     Internet
# 199   SGAAG0045     phuongnam.taipq1     Internet
#
#                                     Nội dung tiếp nhận      Ngày tiếp nhận  \
# 0    call - LÂM HỒNG PHÚ - SGAAB0147 - 0946210462 -... 2024-11-06 12:37:14
# 1    SGAAB0156 - 0908020082 - có 1 Camera ko kết nố... 2024-11-05 12:57:13
# 2    SGAAB2614 - 0908991897 - CÔNG TY TNHH GLOBAL S... 2024-11-02 10:35:23
# 3    SGAAB2862 - 0933662540 - NGUYỄN THỊ DIỄM HẰNG:... 2024-11-07 12:03:16
# 4    SGAAB7344 - 0944534350 - so chinh chu:  kh báo... 2024-11-14 10:19:23
# ..                                                 ...                 ...
# 195  SGJ119247 - 0944333696 - cc:   KH yêu cầu than... 2024-11-08 11:38:19
# 196  Huỳnh Thị Từ Quyên - SGJ126307, 0342439048, c.... 2024-11-09 11:06:20
# 197  DUONG DINH THIEN NHAN - SGAAC5456 - 0972719402... 2024-11-04 12:12:02
# 198  TU SANG THUAN - SGAAE0877 - 0907437400 - CC: k... 2024-11-07 16:04:03
# 199  SGAAG0045 - 0974188388 - C. Thủy: KH muốn th-l... 2024-11-12 10:17:23
#
#          Ngày phân công  Kết quả liên lạc  ... Người xử lý hiện tại  \
# 0   2024-11-06 12:37:14  Gặp trực tiếp KH  ...                Mydc2
# 1   2024-11-05 14:25:00  Gặp trực tiếp KH  ...           phuongnhb2
# 2   2024-11-02 10:35:23  Gặp trực tiếp KH  ...               Hongnk
# 3   2024-11-07 12:03:16  Gặp trực tiếp KH  ...            Dungnt276
# 4   2024-11-14 10:19:23  Gặp trực tiếp KH  ...              Quyntx3
# ..                  ...               ...  ...                  ...
# 195 2024-11-08 11:38:19  Gặp trực tiếp KH  ...              KhoiLTD
# 196 2024-11-09 11:06:20  Gặp trực tiếp KH  ...    Phuongnam.PhucPTH
# 197 2024-11-04 12:12:02  Gặp trực tiếp KH  ...            quynhnt58
# 198 2024-11-07 16:04:03  Gặp trực tiếp KH  ...                Vytnm
# 199 2024-11-12 10:17:23  Gặp trực tiếp KH  ...             Thinhntc
#
#     Thời gian xử lý hoàn tất Tình trạng xử lý của yêu cầu Gói dịch vụ  \
# 0        2024-11-07 09:34:18                     Đã xử lý         Sky
# 1        2024-11-08 09:18:20                     Đã xử lý        Meta
# 2        2024-11-02 11:50:31                     Đã xử lý        Meta
# 3        2024-11-08 14:52:58                     Đã xử lý        Giga
# 4        2024-11-14 11:08:12                     Đã xử lý         Sky
# ..                       ...                          ...         ...
# 195      2024-11-08 13:56:15                     Đã xử lý        Giga
# 196      2024-11-13 14:22:35        Kết thúc theo yêu cầu        Giga
# 197      2024-11-05 15:59:14                     Đã xử lý        Giga
# 198      2024-11-08 09:08:33                     Đã xử lý        Meta
# 199                      NaT                   Đang xử lý         Sky
#
#     Gói DV tính cước Số tháng sử dụng    Tình trạng NET hiện tại  \
# 0                Sky               34                Bình thường
# 1               Meta               34                Bình thường
# 2               Meta               33                Bình thường
# 3               Giga               33                Bình thường
# 4                Sky               33                Bình thường
# ..               ...              ...                        ...
# 195             Giga               35                Bình thường
# 196             Giga               35                Bình thường
# 197             Giga               33  Ngưng vì lý do thanh toán
# 198             Meta               33                Bình thường
# 199              Sky               32                Bình thường
#
#     Tình trạng PayTV hiện tại Tình trạng NET khi lên CR  \
# 0                 Bình thường               Bình thường
# 1                 Bình thường               Bình thường
# 2                         NaN               Bình thường
# 3                 Bình thường               Bình thường
# 4                 Bình thường               Bình thường
# ..                        ...                       ...
# 195               Bình thường               Bình thường
# 196                       NaN               Bình thường
# 197               Bình thường               Bình thường
# 198                       NaN               Bình thường
# 199               Bình thường               Bình thường
#
#             phone_numbers 2
# 0    0946210462, 0921280579
# 1                0908020082
# 2                0908991897
# 3                0933662540
# 4                0944534350
# ..                      ...
# 195  0944333696, 0944333696
# 196              0342439048
# 197              0972719402
# 198              0907437400
# 199              0974188388
#
# [200 rows x 33 columns]

# %%
df.to_excel('Thy Anh nè.xlsx', index=False)
